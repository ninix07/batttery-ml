# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import linear_model
from scipy.optimize import curve_fit
from scipy.io import loadmat
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler

# %%
data= pd.read_csv("./assets/battery-history-csvs/batteryreport.csv")

# %%
data.head()
# Out:
#     date_time  capacity        state
# 0  1698037940     27735     Charging
# 1  1697979425     12405  Discharging
# 2  1697978524     14040  Discharging
# 3  1698067801     40005  Discharging
# 4  1698438307     33735  Discharging

# %%
data['date_time'] = pd.to_datetime(data['date_time'], unit='s')

# %%
print(data.shape)
# Out:
# (168, 3)

# %%
data=data.sort_values(by=['date_time'],ascending=True)

# %%
discharging_data=data[data['state']=="Discharging"]
required_data=discharging_data.drop("state", axis='columns')
required_data
# Out:
#               date_time  capacity
# 16  2023-10-18 23:10:47     25365
# 84  2023-10-19 00:43:58     25170
# 49  2023-10-19 01:26:12     16800
# 34  2023-10-19 11:05:47     14430
# 127 2023-10-19 11:34:22     11175
# ..                  ...       ...
# 26  2023-11-01 03:25:17     40380
# 62  2023-11-01 03:28:45     40365
# 92  2023-11-01 04:07:41     36735
# 15  2023-11-01 04:11:07     36630
# 138 2023-11-01 05:01:53     31770
#
# [115 rows x 2 columns]

# %%
diff_data=required_data.diff()

# %%
diff_data=diff_data.dropna()

# %%
diff_data['date_time'] = pd.to_timedelta(diff_data['date_time'])
diff_data['capacity']=diff_data['capacity'].abs()
diff_data = diff_data[diff_data['capacity']!=0]
diff_data['minutes'] = diff_data['date_time'].dt.total_seconds()/60

# %%
diff_data.head()
# Out:
#           date_time  capacity     minutes
# 84  0 days 01:33:11     195.0   93.183333
# 49  0 days 00:42:14    8370.0   42.233333
# 34  0 days 09:39:35    2370.0  579.583333
# 127 0 days 00:28:35    3255.0   28.583333
# 86  0 days 02:17:43   32745.0  137.716667

# %%
plt.scatter(diff_data['capacity'], diff_data['minutes'])

# %%
x_values=diff_data['capacity'].values
y_values=diff_data['minutes'].values
x_new = np.linspace(min(x_values), max(x_values), 100)

# %%
coefficients = np.polyfit(x_values, y_values, 1)

# %%
best_fit_line = np.polyval(coefficients, x_values)
y_interp = np.polyval(np.polyfit(x_values, y_values, 1), x_new)

# %%
plt.scatter(x_values, y_values, label='Data')
plt.plot(x_values, best_fit_line, label='Best Fit Line', color='red')
plt.xlabel('Capacity')
plt.ylabel('Minutes')
plt.title('Best Fit Line between Capacity and Minutes')
# Out:
# Text(0.5, 1.0, 'Best Fit Line between Capacity and Minutes')

# %%
plt.scatter(x_values, y_values, label='Known Points')
plt.plot(x_new, y_interp, 'r-', label='Interpolated Curve')
plt.xlabel('Capacity')
plt.ylabel('Minutes')
plt.title('Interpolated Curve')
# Out:
# Text(0.5, 1.0, 'Interpolated Curve')

# %%
data_slope = pd.DataFrame(columns=['prev_time', 'curr_time', 'prev_capacity', 'curr_capacity'])


data_slope['prev_time'] = data['date_time'].shift()
data_slope['curr_time'] = data['date_time']
data_slope['prev_capacity'] = data['capacity'].shift()
data_slope['curr_capacity'] = data['capacity']

# %%
data_slope.head()
# Out:
#               prev_time           curr_time  prev_capacity  curr_capacity
# 16                  NaT 2023-10-18 23:10:47            NaN          25365
# 84  2023-10-18 23:10:47 2023-10-19 00:43:58        25365.0          25170
# 49  2023-10-19 00:43:58 2023-10-19 01:26:12        25170.0          16800
# 34  2023-10-19 01:26:12 2023-10-19 11:05:47        16800.0          14430
# 127 2023-10-19 11:05:47 2023-10-19 11:34:22        14430.0          11175

# %%
data_slope=data_slope.dropna()

# %%
data_slope['time_diff']=(data_slope['curr_time'] - data_slope['prev_time']).dt.total_seconds()
data_slope['slope'] = (data_slope['curr_capacity'] - data_slope['prev_capacity']) / data_slope['time_diff']

# %%
data_slope.head()
# Out:
#               prev_time           curr_time  prev_capacity  curr_capacity  \
# 84  2023-10-18 23:10:47 2023-10-19 00:43:58        25365.0          25170
# 49  2023-10-19 00:43:58 2023-10-19 01:26:12        25170.0          16800
# 34  2023-10-19 01:26:12 2023-10-19 11:05:47        16800.0          14430
# 127 2023-10-19 11:05:47 2023-10-19 11:34:22        14430.0          11175
# 160 2023-10-19 11:34:22 2023-10-19 12:22:37        11175.0          10890
#
#      time_diff     slope
# 84      5591.0 -0.034877
# 49      2534.0 -3.303078
# 34     34775.0 -0.068152
# 127     1715.0 -1.897959
# 160     2895.0 -0.098446

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data_slope['slope'], data_slope['curr_capacity'] - data_slope['prev_capacity'], (data_slope['time_diff']))
ax.set_xlabel('Slope')
ax.set_ylabel('Capacity Difference')
ax.set_zlabel('Time Difference (seconds)')

plt.show()

# %%
model = linear_model.LinearRegression()

# %%
X = data_slope[['slope', 'curr_capacity', 'prev_capacity']]
y=data_slope['time_diff']

# %%
model.fit(X, y)
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
# Out:
# Coefficients: [-1.47932462e+02  1.40465455e-01 -1.61480972e-01]
# Intercept: 7553.638896097192

# %%
y_pred = model.predict(X)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data_slope['slope'], data_slope['curr_capacity'] - data_slope['prev_capacity'], y_pred, label='Regression Plane', color='red')

ax.set_xlabel('Slope')
ax.set_ylabel('Capacity Difference')
ax.set_zlabel('Time Difference (seconds)')

ax.legend()

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data_slope['slope'], data_slope['curr_capacity'] - data_slope['prev_capacity'], y_pred, label='Regression Plane', color='red')
ax.scatter(data_slope['slope'], data_slope['curr_capacity'] - data_slope['prev_capacity'], (data_slope['time_diff']))

ax.set_xlabel('Slope')
ax.set_ylabel('Capacity Difference')
ax.set_zlabel('Time Difference (seconds)')

ax.legend()

plt.show()

# %%
import tensorflow as tf

# %%
# nn_data=pd.read_excel("./data/batteryDischargeData/UUT2_BatteryModule_Discharge.xlsx",sheet_name=None)
# df = pd.concat(list(nn_data.values()), ignore_index=True)

# %%
# df.drop(columns=['UUT2P1 Voltage\n [V ]', 'UUT2P2 Voltage\n[V] ', 'UUT2P3 Voltage\n [V] ', 'UUT2P4 Voltage\n[V] '],inplace=True)

# %%
# df.head()

# %%
# df.columns

# %%
# df.drop(columns=['UUT2P1 Temp\n[⁰C]', 'UUT2P2 Temp\n[⁰C]', 'UUT2P3 Temp\n[⁰C]', 'UUT2P4 Temp\n[⁰C]'],inplace=True)

# %%
# df.head()

# %%
# X=df[['Test capacity\n[Ah]','Test current\n[A]']].values
# y=df['Time\n[s]'].values

# %%
# model = tf.keras.Sequential()
# model.add(tf.keras.layers.Dense(64, activation='relu'))
# model.add(tf.keras.layers.Dense(32, activation='relu'))

# model.add(tf.keras.layers.Dense(1, activation='linear'))

# %%
# model.compile(optimizer='adam', loss='mean_squared_error')
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# model.fit(X,y,epochs=100,batch_size=50,validation_split=0.2,callbacks=[early_stopping])

# %%
# model.summary()

# %%
# y_pred = model.predict(X)

# %%
# rmse = np.sqrt(mean_squared_error(y, y_pred))

# %%
# print(rmse)

# %%
# df1=pd.DataFrame(y_pred,columns=['prediction'])
# df2=pd.DataFrame(np.array(y),columns=['actual'])

# %%
# result_df = pd.concat([df1, df2], axis=1)

# %%
# result_df.head()

# %%
# random_sample = result_df.sample(n=40, random_state=42)  # Set random_state for reproducibility

# # Display the randomly selected sample
# print(random_sample)

# %%
log_data=pd.read_csv("./data/battery_log_bishal.csv",header=None,index_col=False)

# %%
log_data.head()
# Out:
#                                    0  1            2  \
# 0  2023-12-16 04:46:20.700838100 UTC  0  discharging
# 1  2023-12-16 04:46:20.703746100 UTC  0  discharging
# 2  2023-12-16 04:46:50.699399100 UTC  0  discharging
# 3  2023-12-16 04:47:20.714960700 UTC  0  discharging
# 4  2023-12-16 04:47:50.707890100 UTC  0  discharging
#
#                                3                      4  \
# 0   14.551001 m^2 kg^1 s^-3 A^-1  76734.0 m^2 kg^1 s^-2
# 1   14.551001 m^2 kg^1 s^-3 A^-1  76734.0 m^2 kg^1 s^-2
# 2   14.629001 m^2 kg^1 s^-3 A^-1  76518.0 m^2 kg^1 s^-2
# 3  14.7300005 m^2 kg^1 s^-3 A^-1  76302.0 m^2 kg^1 s^-2
# 4      14.732 m^2 kg^1 s^-3 A^-1  76140.0 m^2 kg^1 s^-2
#
#                          5
# 0   8.190001 m^2 kg^1 s^-3
# 1   8.190001 m^2 kg^1 s^-3
# 2        5.4 m^2 kg^1 s^-3
# 3      4.875 m^2 kg^1 s^-3
# 4  7.7100005 m^2 kg^1 s^-3

# %%
log_data.columns=["Date","Battery Index","Battery State","Voltage[V]","Energy[J]", "Energy_Rate[J/s]"]

# %%
log_data.head()
# Out:
#                                 Date  Battery Index Battery State  \
# 0  2023-12-16 04:46:20.700838100 UTC              0   discharging
# 1  2023-12-16 04:46:20.703746100 UTC              0   discharging
# 2  2023-12-16 04:46:50.699399100 UTC              0   discharging
# 3  2023-12-16 04:47:20.714960700 UTC              0   discharging
# 4  2023-12-16 04:47:50.707890100 UTC              0   discharging
#
#                       Voltage[V]              Energy[J]  \
# 0   14.551001 m^2 kg^1 s^-3 A^-1  76734.0 m^2 kg^1 s^-2
# 1   14.551001 m^2 kg^1 s^-3 A^-1  76734.0 m^2 kg^1 s^-2
# 2   14.629001 m^2 kg^1 s^-3 A^-1  76518.0 m^2 kg^1 s^-2
# 3  14.7300005 m^2 kg^1 s^-3 A^-1  76302.0 m^2 kg^1 s^-2
# 4      14.732 m^2 kg^1 s^-3 A^-1  76140.0 m^2 kg^1 s^-2
#
#           Energy_Rate[J/s]
# 0   8.190001 m^2 kg^1 s^-3
# 1   8.190001 m^2 kg^1 s^-3
# 2        5.4 m^2 kg^1 s^-3
# 3      4.875 m^2 kg^1 s^-3
# 4  7.7100005 m^2 kg^1 s^-3

# %%
log_data['Voltage[V]'] = log_data['Voltage[V]'].str.extract(r'([-+]?\d*\.\d+|\d+)').astype(float)
log_data['Energy[J]'] = log_data['Energy[J]'].str.extract(r'([-+]?\d*\.\d+|\d+)').astype(float)
log_data['Energy_Rate[J/s]'] = log_data['Energy_Rate[J/s]'].str.extract(r'([-+]?\d*\.\d+|\d+)').astype(float)

# %%
log_data.head()
# Out:
#                                 Date  Battery Index Battery State  Voltage[V]  \
# 0  2023-12-16 04:46:20.700838100 UTC              0   discharging   14.551001
# 1  2023-12-16 04:46:20.703746100 UTC              0   discharging   14.551001
# 2  2023-12-16 04:46:50.699399100 UTC              0   discharging   14.629001
# 3  2023-12-16 04:47:20.714960700 UTC              0   discharging   14.730000
# 4  2023-12-16 04:47:50.707890100 UTC              0   discharging   14.732000
#
#    Energy[J]  Energy_Rate[J/s]
# 0    76734.0          8.190001
# 1    76734.0          8.190001
# 2    76518.0          5.400000
# 3    76302.0          4.875000
# 4    76140.0          7.710000

# %%
# log_data.dropna()
# log_data['time[s]']=log_data['Energy[J]']/log_data['Energy_Rate[J/s]']

# %%
# log_data.head()

# %%
# log_data.replace([np.inf, -np.inf], np.nan, inplace=True)
# log_data.dropna(inplace=True)
log_data = log_data[log_data['Battery State'] == 'discharging']
log_data['Date'] = pd.to_datetime(log_data['Date'])
log_data['Time Difference[s]']=log_data['Date'].diff().dt.total_seconds()
log_data['Capacity Difference[J]']=log_data['Energy[J]'].diff()
log_data.dropna(inplace=True)

# %%
log_data.head()
# Out:
#                                  Date  Battery Index Battery State  \
# 2 2023-12-16 04:46:50.699399100+00:00              0   discharging
# 3 2023-12-16 04:47:20.714960700+00:00              0   discharging
# 4 2023-12-16 04:47:50.707890100+00:00              0   discharging
# 5 2023-12-16 04:48:20.699026100+00:00              0   discharging
# 6 2023-12-16 04:48:50.706117900+00:00              0   discharging
#
#    Voltage[V]  Energy[J]  Energy_Rate[J/s]  Time Difference[s]  \
# 2   14.629001    76518.0             5.400           29.995653
# 3   14.730000    76302.0             4.875           30.015562
# 4   14.732000    76140.0             7.710           29.992929
# 5   14.709001    75924.0             5.400           29.991136
# 6   14.615001    75708.0             8.250           30.007092
#
#    Capacity Difference[J]
# 2                  -216.0
# 3                  -216.0
# 4                  -162.0
# 5                  -216.0
# 6                  -216.0

# %%
scaler = MinMaxScaler()
log_data['Capacity Difference[J]']=scaler.fit_tra
X_log=log_data[['Energy_Rate[J/s]','Voltage[V]','Capacity Difference[J]']].values
y_log=log_data['Time Difference[s]'].values

X_log_normalized = scaler.fit_transform(X_log)

# %%
Battery_model = tf.keras.Sequential()
Battery_model.add(tf.keras.layers.Dense(64, activation='relu'))
Battery_model.add(tf.keras.layers.Dense(32, activation='relu'))
Battery_model.add(tf.keras.layers.Dense(1, activation='linear'))

# %%
Battery_model.compile(optimizer='adam', loss='mean_squared_error')
# early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
Battery_model.fit(X_log_normalized,y_log,epochs=50,batch_size=10,validation_split=0.2)
# Out:
# Epoch 1/50
# 43/43 [==============================] - 1s 4ms/step - loss: 23556.3945 - val_loss: 27682.3535
# Epoch 2/50
# 43/43 [==============================] - 0s 2ms/step - loss: 23520.8047 - val_loss: 27644.4609
# Epoch 3/50
# 43/43 [==============================] - 0s 3ms/step - loss: 23468.2812 - val_loss: 27584.2461
# Epoch 4/50
# 43/43 [==============================] - 0s 3ms/step - loss: 23379.0215 - val_loss: 27496.2969
# Epoch 5/50
# 43/43 [==============================] - 0s 3ms/step - loss: 23244.9688 - val_loss: 27386.0703
# Epoch 6/50
# 43/43 [==============================] - 0s 2ms/step - loss: 23101.3477 - val_loss: 27285.7910
# Epoch 7/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22943.5117 - val_loss: 27228.0547
# Epoch 8/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22805.1035 - val_loss: 27154.3711
# Epoch 9/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22711.3184 - val_loss: 27138.3984
# Epoch 10/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22652.2246 - val_loss: 27139.9004
# Epoch 11/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22613.6855 - val_loss: 27142.3965
# Epoch 12/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22579.0469 - val_loss: 27168.7578
# Epoch 13/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22551.0039 - val_loss: 27175.6914
# Epoch 14/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22543.9434 - val_loss: 27190.3086
# Epoch 15/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22544.5703 - val_loss: 27169.3730
# Epoch 16/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22527.1660 - val_loss: 27221.5410
# Epoch 17/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22500.2402 - val_loss: 27217.9160
# Epoch 18/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22504.0645 - val_loss: 27232.1719
# Epoch 19/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22489.1855 - val_loss: 27216.5488
# Epoch 20/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22470.5430 - val_loss: 27240.0273
# Epoch 21/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22472.5996 - val_loss: 27251.9082
# Epoch 22/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22461.1777 - val_loss: 27247.2891
# Epoch 23/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22445.9902 - val_loss: 27247.7891
# Epoch 24/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22453.0723 - val_loss: 27244.7969
# Epoch 25/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22428.2988 - val_loss: 27255.5918
# Epoch 26/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22421.1855 - val_loss: 27256.9531
# Epoch 27/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22422.0508 - val_loss: 27222.6641
# Epoch 28/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22434.5996 - val_loss: 27261.3027
# Epoch 29/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22395.4180 - val_loss: 27245.8281
# Epoch 30/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22400.5312 - val_loss: 27229.0156
# Epoch 31/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22378.3496 - val_loss: 27266.3164
# Epoch 32/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22364.7227 - val_loss: 27267.3984
# Epoch 33/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22360.6543 - val_loss: 27266.5039
# Epoch 34/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22351.9961 - val_loss: 27262.1172
# Epoch 35/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22341.4316 - val_loss: 27262.4590
# Epoch 36/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22323.9238 - val_loss: 27259.9043
# Epoch 37/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22316.8555 - val_loss: 27266.8867
# Epoch 38/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22310.3438 - val_loss: 27251.8965
# Epoch 39/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22308.6504 - val_loss: 27231.9238
# Epoch 40/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22287.2422 - val_loss: 27272.5137
# Epoch 41/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22268.6699 - val_loss: 27273.5391
# Epoch 42/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22257.0098 - val_loss: 27259.4102
# Epoch 43/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22242.4355 - val_loss: 27263.7285
# Epoch 44/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22235.1504 - val_loss: 27274.2363
# Epoch 45/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22226.9883 - val_loss: 27262.9141
# Epoch 46/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22207.9062 - val_loss: 27267.7363
# Epoch 47/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22194.0840 - val_loss: 27260.4863
# Epoch 48/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22177.4453 - val_loss: 27268.9590
# Epoch 49/50
# 43/43 [==============================] - 0s 2ms/step - loss: 22171.5020 - val_loss: 27271.2637
# Epoch 50/50
# 43/43 [==============================] - 0s 3ms/step - loss: 22151.0508 - val_loss: 27256.9453

# %%
Battery_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                256
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2369 (9.25 KB)
# Trainable params: 2369 (9.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_log_pred = Battery_model.predict(X_log_normalized)
# Out:
# 17/17 [==============================] - 0s 1ms/step

# %%
rmse = np.sqrt(mean_squared_error(y_log, y_log_pred))
print(rmse)
# Out:
# 152.1650584609879

# %%
df1=pd.DataFrame(y_log_pred,columns=['prediction'])
df2=pd.DataFrame(np.array(y_log),columns=['actual'])
result_df = pd.concat([df1, df2], axis=1)

# %%
random_sample = result_df.sample(n=40, random_state=42)  # Set random_state for reproducibility

# Display the randomly selected sample
print(random_sample)
# Out:
#      prediction       actual
# 117   29.317114    30.008313
# 132   28.953903    29.993516
# 154   28.479082    29.999237
# 245   26.119616    30.001670
# 84    29.257994    29.998508
# 346   40.107018     0.000478
# 6     30.292429    29.989537
# 478   34.984554  1722.356830
# 182   27.783070    30.002603
# 55    30.407068    29.994932
# 104   29.450876    30.001031
# 531   35.203861     0.001792
# 320   40.107018     0.000483
# 249   27.466152   655.632945
# 237   26.338530    30.012793
# 469   32.257545    29.998819
# 524   35.203861     0.002488
# 357   40.107018     0.000589
# 211   26.774244    29.993168
# 446   35.503872     0.001955
# 10    33.517357    29.989651
# 404   33.401340    30.002143
# 148   28.658251    29.992709
# 451   34.189945    30.002276
# 2     32.509892    29.992929
# 416   35.503872     0.001031
# 504   35.203861     0.007808
# 185   28.065470    30.003826
# 412   35.503872     0.001411
# 195   25.107618    29.994934
# 515   35.203861     0.001973
# 488   35.203861     0.003307
# 476   32.592449    29.995459
# 352   40.107018     0.000712
# 158   28.406208    30.001959
# 229   26.679262    29.996272
# 425   35.503872     0.001306
# 86    29.384022    30.008111
# 77    29.523363    30.000216
# 131   29.113384    30.009153

# %%
Battery_model.save("Battery_model")
# Out:
# INFO:tensorflow:Assets written to: Battery_model\assets
# INFO:tensorflow:Assets written to: Battery_model\assets

# %%
model = load_model("Battery_model")

# %%
print(X_log)
# Out:
# [[   5.4         14.629001  -216.       ]
#  [   4.875       14.7300005 -216.       ]
#  [   7.7100005   14.732     -162.       ]
#  ...
#  [  10.755       14.824        0.       ]
#  [  10.755       14.824        0.       ]
#  [  11.97        14.686001  -108.       ]]
